# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# !nvidia-smi
# Out:
# Tue Jan 24 04:13:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
cd /content/drive/MyDrive/산학
# Out:
# /content/drive/MyDrive/산학

# %%
# !pip install transformers
# !pip install pytorch_lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 102.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 27.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.21.6)
# Collecting lightning-utilities>=0.4.2
#   Downloading lightning_utilities-0.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (2022.11.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.13.1+cu116)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 54.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.64.1)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.25.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=17.1->pytorch_lightning) (3.0.9)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (22.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.0)
# Installing collected packages: torchmetrics, lightning-utilities, pytorch_lightning
# Successfully installed lightning-utilities-0.6.0 pytorch_lightning-1.9.0 torchmetrics-0.11.0

# %%
# !pip install torch
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)

# %%
# !pip install datasets transformers[sentencepiece]
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (21.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (3.9.0)
# Requirement already satisfied: protobuf<=3.20.2 in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (3.19.6)
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (4.0.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: sentencepiece, xxhash, urllib3, multiprocess, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.8.0 multiprocess-0.70.14 responses-0.18.0 sentencepiece-0.1.97 urllib3-1.26.14 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (0.1.97)

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
from itertools import chain
from string import punctuation

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
import csv
from dataclasses import dataclass

from enum import Enum
from typing import List, Optional
from transformers import PreTrainedTokenizer

# %%
# !pip install rich[jupyter]

# Importing libraries
import os
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
import os

# Importing the T5 modules from huggingface/transformers
from transformers import T5Tokenizer, T5ForConditionalGeneration

# rich: for a better display on terminal
from rich.table import Column, Table
from rich import box
from rich.console import Console

# define a rich console logger
console = Console(record = True)

# to display dataframe in ASCII format
def display_df(df):
    """display dataframe in ASCII format"""

    console = Console()
    table = Table(
        Column("source_text", justify="center"),
        Column("target_text", justify="center"),
        title="Sample Data",
        pad_edge=False,
        box=box.ASCII,
    )

    for i, row in enumerate(df.values.tolist()):
        table.add_row(row[0], row[1])

    console.print(table)

# training logger to log training progress
training_logger = Table(
    Column("Epoch", justify="center"),
    Column("Steps", justify="center"),
    Column("Loss", justify="center"),
    title="Training Status",
    pad_edge=False,
    box=box.ASCII,
)

# Setting up the device for GPU usage
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rich[jupyter] in /usr/local/lib/python3.8/dist-packages (13.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich[jupyter]) (2.6.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from rich[jupyter]) (2.1.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from rich[jupyter]) (4.4.0)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.5.1 in /usr/local/lib/python3.8/dist-packages (from rich[jupyter]) (7.7.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (7.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (3.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.7.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py<3.0.0,>=2.1.0->rich[jupyter]) (0.1.2)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.18.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.1.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (23.2.1)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.6.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.15.0)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.11.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.13.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.6.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.0.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (2.16.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (5.10.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]) (3.11.0)

# %%
class YourDataSetClass(Dataset):
    """
    Creating a custom dataset for reading the dataset and
    loading it into the dataloader to pass it to the
    neural network for finetuning the model

    """

    def __init__(
        self, dataframe, tokenizer, source_len, target_len, source_text, target_text
    ):
        """
        Initializes a Dataset class

        Args:
            dataframe (pandas.DataFrame): Input dataframe
            tokenizer (transformers.tokenizer): Transformers tokenizer
            source_len (int): Max length of source text
            target_len (int): Max length of target text
            source_text (str): column name of source text
            target_text (str): column name of target text
        """
        self.tokenizer = tokenizer
        self.data = dataframe
        self.source_len = source_len
        self.summ_len = target_len
        self.target_text = self.data[target_text]
        self.source_text = self.data[source_text]

    def __len__(self):
        """returns the length of dataframe"""

        return len(self.target_text)

    def __getitem__(self, index):
        """return the input ids, attention masks and target ids"""

        source_text = str(self.source_text[index])
        target_text = str(self.target_text[index])

        # cleaning data so as to ensure data is in string type
        source_text = " ".join(source_text.split())
        target_text = " ".join(target_text.split())

        source = self.tokenizer.batch_encode_plus(
            [source_text],
            max_length=self.source_len,
            pad_to_max_length=True,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )
        target = self.tokenizer.batch_encode_plus(
            [target_text],
            max_length=self.summ_len,
            pad_to_max_length=True,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )

        source_ids = source["input_ids"].squeeze()
        source_mask = source["attention_mask"].squeeze()
        target_ids = target["input_ids"].squeeze()
        target_mask = target["attention_mask"].squeeze()

        return {
            "source_ids": source_ids.to(dtype=torch.long),
            "source_mask": source_mask.to(dtype=torch.long),
            "target_ids": target_ids.to(dtype=torch.long),
            "target_ids_y": target_ids.to(dtype=torch.long),
        }

# %%
def train(epoch, tokenizer, model, device, loader, optimizer):

    """
    Function to be called for training with the parameters passed from main function

    """
    model.train()
    for _, data in enumerate(loader, 0):
        y = data["target_ids"].to(device, dtype=torch.long)
        y_ids = y[:, :-1].contiguous()
        lm_labels = y[:, 1:].clone().detach()
        lm_labels[y[:, 1:] == tokenizer.pad_token_id] = -100
        ids = data["source_ids"].to(device, dtype=torch.long)
        mask = data["source_mask"].to(device, dtype=torch.long)

        outputs = model(
            input_ids=ids,
            attention_mask=mask,
            decoder_input_ids=y_ids,
            labels=lm_labels,
        )
        loss = outputs[0]

        if _ % 300 == 0:
            training_logger.add_row(str(epoch), str(_), str(loss))
            console.print(training_logger)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
from sklearn.metrics import accuracy_score, f1_score
def validate(epoch, tokenizer, model, device, loader):

  """
  Function to evaluate model for predictions

  """
  model.eval()
  predictions = []
  actuals = []
  accuracy = 0.0
  f1 = 0.0
  with torch.no_grad():
      for _, data in enumerate(loader, 0):
          y = data['target_ids'].to(device, dtype = torch.long)
          ids = data['source_ids'].to(device, dtype = torch.long)
          mask = data['source_mask'].to(device, dtype = torch.long)

          generated_ids = model.generate(
              input_ids = ids,
              attention_mask = mask, 
              max_length=150, 
              num_beams=2,
              repetition_penalty=2.5, 
              length_penalty=1.0, 
              early_stopping=True
              )
          preds = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True) for g in generated_ids]
          target = [tokenizer.decode(t, skip_special_tokens=True, clean_up_tokenization_spaces=True)for t in y]
          
          accuracy += accuracy_score(target, preds)
          f1 += f1_score(target, preds, average = 'macro')
          if _%10==0:
              console.print('accuracy score : {0:.4f}, f1 score : {1:.4f}'.format(accuracy / 10, f1 / 10))
              console.print(f'Completed {_}')
              accuracy = 0.0
              f1 = 0.0

          predictions.extend(preds)
          actuals.extend(target)
  return predictions, actuals

# %%
def T5Trainer(dataframe, source_text, target_text, model_params, output_dir="./outputs/" ,step = "test",):
  
  """
  T5 trainer

  """

  # Set random seeds and deterministic pytorch for reproducibility
  torch.manual_seed(model_params["SEED"]) # pytorch random seed
  np.random.seed(model_params["SEED"]) # numpy random seed
  torch.backends.cudnn.deterministic = True

  # logging
  console.log(f"""[Model]: Loading {model_params["MODEL"]}...\n""")

  # tokenzier for encoding the text
  tokenizer = T5Tokenizer.from_pretrained(model_params["MODEL"])

  # Defining the model. We are using t5-base model and added a Language model layer on top for generation of Summary. 
  # Further this model is sent to device (GPU/TPU) for using the hardware.
  model = T5ForConditionalGeneration.from_pretrained(model_params["MODEL"])
  model = model.to(device)
  
  # logging
  console.log(f"[Data]: Reading data...\n")

  # Importing the raw dataset
  dataframe = dataframe[[source_text,target_text]]
  display_df(dataframe.head(2))

  
  # Creation of Dataset and Dataloader
  # Defining the train size. So 80% of the data will be used for training and the rest for validation. 
  #train_size = 0.8
  #train_dataset=dataframe.sample(frac=train_size,random_state = model_params["SEED"])
  train_dataset = dataframe.iloc[:26796]
  #val_dataset = dataframe.iloc[26796:30774]
  val_dataset = dataframe.iloc[30774:]
  #val_dataset=dataframe.drop(train_dataset.index).reset_index(drop=True)
  #train_dataset = train_dataset.reset_index(drop=True)

  console.print(f"FULL Dataset: {dataframe.shape}")
  console.print(f"TRAIN Dataset: {train_dataset.shape}")
  console.print(f"VALID Dataset: {val_dataset.shape}")
  #console.print(f"TEST Dataset: {test_dataset.shape}")


  # Creating the Training and Validation dataset for further creation of Dataloader
  training_set = YourDataSetClass(train_dataset, tokenizer, model_params["MAX_SOURCE_TEXT_LENGTH"], model_params["MAX_TARGET_TEXT_LENGTH"], source_text, target_text)
  val_set = YourDataSetClass(val_dataset, tokenizer, model_params["MAX_SOURCE_TEXT_LENGTH"], model_params["MAX_TARGET_TEXT_LENGTH"], source_text, target_text)
  #test_set = YourDataSetClass(test_dataset, tokenizer, model_params["MAX_SOURCE_TEXT_LENGTH"], model_params["MAX_TARGET_TEXT_LENGTH"], source_text, target_text)
  

  # Defining the parameters for creation of dataloaders
  train_params = {
      'batch_size': model_params["TRAIN_BATCH_SIZE"],
      'shuffle': True,
      'num_workers': 0
      }


  val_params = {
      'batch_size': model_params["VALID_BATCH_SIZE"],
      'shuffle': False,
      'num_workers': 0
      }

  test_params = {
      'batch_size': model_params["VALID_BATCH_SIZE"],
      'shuffle': False,
      'num_workers': 0
  }

  # Creation of Dataloaders for testing and validation. This will be used down for training and validation stage for the model.
  training_loader = DataLoader(training_set, **train_params)
  val_loader = DataLoader(val_set, **val_params)
  #test_loader = DataLoader(test_set, **test_params)


  # Defining the optimizer that will be used to tune the weights of the network in the training session. 
  optimizer = torch.optim.Adam(params =  model.parameters(), lr=model_params["LEARNING_RATE"])


  # Training loop
  console.log(f'[Initiating Fine Tuning]...\n')
  if step != "test":
    for epoch in range(model_params["TRAIN_EPOCHS"]):
        train(epoch, tokenizer, model, device, training_loader, optimizer)
        
        console.log(f"[Saving Model]...\n")
        #Saving the model after training
        path = os.path.join(output_dir, "model_files")
        model.save_pretrained(path)
        tokenizer.save_pretrained(path)


  # evaluating test dataset
  console.log(f"[Initiating Validation]...\n")
  for epoch in range(model_params["VAL_EPOCHS"]):
    predictions, actuals = validate(epoch, tokenizer, model, device, val_loader)
    final_df = pd.DataFrame({'Generated Text':predictions,'Actual Text':actuals})
    final_df.to_csv(os.path.join(output_dir,'predictions.csv'))
  
  console.save_text(os.path.join(output_dir,'logs.txt'))
  
  console.log(f"[Validation Completed.]\n")
  console.print(f"""[Model] Model saved @ {os.path.join(output_dir, "model_files")}\n""")
  console.print(f"""[Validation] Generation on Validation data saved @ {os.path.join(output_dir,'predictions.csv')}\n""")
  console.print(f"""[Logs] Logs saved @ {os.path.join(output_dir,'logs.txt')}\n""")

# %%
# let's define model parameters specific to T5
model_params = {
    "MODEL": "/content/drive/MyDrive/산학/outputs/model_files",  # model_type: t5-base/t5-large
    "TRAIN_BATCH_SIZE": 8,  # training batch size
    "VALID_BATCH_SIZE": 8,  # validation batch size
    "TRAIN_EPOCHS": 5,  # number of training epochs
    "VAL_EPOCHS": 1,  # number of validation epochs
    "LEARNING_RATE": 1e-4,  # learning rate
    "MAX_SOURCE_TEXT_LENGTH": 512,  # max length of source text
    "MAX_TARGET_TEXT_LENGTH": 3,  # max length of target text
    "SEED": 2022,  # set seed for reproducibility
}

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    auc = roc_auc_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'auroc': auc
    }

# %%
df = pd.read_csv('preprocess.csv')
# let's get a news summary dataset  x
# dataframe has 2 columns: 
#   - text: long article content
#   - headlines: one line summary of news
df['label'] = df['label'].astype(str)

# T5 accepts prefix of the task to be performed:
# Since we are summarizing, let's add summarize to source text as a prefix
dev = pd.read_csv('preprocessing_dev.csv', encoding = 'CP949')
dev = dev.dropna(axis=0)
dev_1 = dev[dev['label'] == 1]
dev_0 = dev[dev['label'] == 0]
dev_0 = dev_0.sample(n=1989, random_state=2023)
dev = pd.concat([dev_0, dev_1])
dev.reset_index(drop=True, inplace=True)
dev = dev.rename(columns = {'noncomment_code' : 'code'})

test = pd.read_csv('preprocessing_test.csv', encoding = 'CP949')
test = test.rename(columns = {'noncomment_code' : 'code'})

data = pd.concat([df, dev, test], axis = 0)
data['label'] = data['label'].astype(str)

T5Trainer(
    dataframe=data,
    source_text="code",
    target_text="label",
    model_params=model_params,
    output_dir="outputs",
)
# Out:
# [10:35:16] [Model]: Loading /content/drive/MyDrive/산학/outputs/model_files...   <ipython-input-82-b2b0b299ebbe>:14
# [10:35:17] [Data]: Reading data...                                               <ipython-input-82-b2b0b299ebbe>:25
#                                                   Sample Data
# +--------------------------------------------------------------------------------------------------------------+
# |                                          source_text                                            | target_text|
# |-------------------------------------------------------------------------------------------------+------------|
# |                                'int MAIN(int argc, char **argv)                                 |      0     |
# |                                                   {                                             |            |
# |                                              int ret=1,i;                                       |            |
# |                                        int verbose=0,Verbose=0;                                 |            |
# |                                            const char **pp;                                     |            |
# |                                             const char *p;                                      |            |
# |                                             int badops=0;                                       |            |
# |                                           SSL_CTX *ctx=NULL;                                    |            |
# |                                             SSL *ssl=NULL;                                      |            |
# |                                          char *ciphers=NULL;                                    |            |
# |                                      const SSL_METHOD *meth=NULL;                               |            |
# |                                       STACK_OF(SSL_CIPHER) *sk;                                 |            |
# |                                              char buf512;                                       |            |
# |                                           BIO *STDout=NULL;                                     |            |
# |                   #if !defined(OPENSSL_NO_SSL2) && !defined(OPENSSL_NO_SSL3)                    |            |
# |                                      meth=SSLv23_server_method();                               |            |
# |                                #elif !defined(OPENSSL_NO_SSL3)                                  |            |
# |                                      meth=SSLv3_server_method();                                |            |
# |                                #elif !defined(OPENSSL_NO_SSL2)                                  |            |
# |                                      meth=SSLv2_server_method();                                |            |
# |                                             #endif                                              |            |
# |                                            apps_startup();                                      |            |
# |                                          if (bio_err == NULL)                                   |            |
# |                                    bio_err=BIO_new_fp(stderr,BIO_NOCLOSE);                      |            |
# |                                 STDout=BIO_new_fp(stdout,BIO_NOCLOSE);                          |            |
# |                                     #ifdef OPENSSL_SYS_VMS                                      |            |
# |                                                   {                                             |            |
# |                               BIO *tmpbio = BIO_new(BIO_f_linebuffer());                        |            |
# |                                   STDout = BIO_push(tmpbio, STDout);                            |            |
# |                                                   }                                             |            |
# |                                             #endif                                              |            |
# |                                    if (!load_config(bio_err, NULL))                             |            |
# |                                                   goto end;                                     |            |
# |                                                argc--;                                          |            |
# |                                                argv++;                                          |            |
# |                                           while (argc >= 1)                                     |            |
# |                                                       {                                         |            |
# |                                          if (strcmp(*argv,"-v") == 0)                           |            |
# |                                                       verbose=1;                                |            |
# |                                       else if (strcmp(*argv,"-V") == 0)                         |            |
# |                                                   verbose=Verbose=1;                            |            |
# |                                    #ifndef OPENSSL_NO_SSL2                                      |            |
# |                                      else if (strcmp(*argv,"-ssl2") == 0)                       |            |
# |                                              meth=SSLv2_client_method();                        |            |
# |                                             #endif                                              |            |
# |                                    #ifndef OPENSSL_NO_SSL3                                      |            |
# |                                      else if (strcmp(*argv,"-ssl3") == 0)                       |            |
# |                                              meth=SSLv3_client_method();                        |            |
# |                                             #endif                                              |            |
# |                                    #ifndef OPENSSL_NO_TLS1                                      |            |
# |                                      else if (strcmp(*argv,"-tls1") == 0)                       |            |
# |                                              meth=TLSv1_client_method();                        |            |
# |                                             #endif                                              |            |
# |                                    else if ((strncmp(*argv,"-h",2) == 0) ||                     |            |
# |                                               (strcmp(*argv,"-?") == 0))                        |            |
# |                                                           {                                     |            |
# |                                                       badops=1;                                 |            |
# |                                                         break;                                  |            |
# |                                                           }                                     |            |
# |                                                      else                                       |            |
# |                                                           {                                     |            |
# |                                                    ciphers= *argv;                              |            |
# |                                                           }                                     |            |
# |                                                    argc--;                                      |            |
# |                                                    argv++;                                      |            |
# |                                                       }                                         |            |
# |                                              if (badops)                                        |            |
# |                                                       {                                         |            |
# |                                  for (pp=ciphers_usage; (*pp != NULL); pp++)                    |            |
# |                                             BIO_printf(bio_err,"%s",*pp);                       |            |
# |                                                   goto end;                                     |            |
# |                                                       }                                         |            |
# |                                     OpenSSL_add_ssl_algorithms();                               |            |
# |                                         ctx=SSL_CTX_new(meth);                                  |            |
# |                                       if (ctx == NULL) goto err;                                |            |
# |                                         if (ciphers != NULL) {                                  |            |
# |                                  if(!SSL_CTX_set_cipher_list(ctx,ciphers)) {                    |            |
# |                                       BIO_printf(bio_err, "Error in cipher list\                |            |
# |                                              ");                                                |            |
# |                                                       goto err;                                 |            |
# |                                                       }                                         |            |
# |                                                   }                                             |            |
# |                                           ssl=SSL_new(ctx);                                     |            |
# |                                       if (ssl == NULL) goto err;                                |            |
# |                                             if (!verbose)                                       |            |
# |                                                       {                                         |            |
# |                                                for (i=0; ; i++)                                 |            |
# |                                                           {                                     |            |
# |                                             p=SSL_get_cipher_list(ssl,i);                       |            |
# |                                                 if (p == NULL) break;                           |            |
# |                                          if (i != 0) BIO_printf(STDout,":");                    |            |
# |                                               BIO_printf(STDout,"%s",p);                        |            |
# |                                                           }                                     |            |
# |                                              BIO_printf(STDout,"\                               |            |
# |                                              ");                                                |            |
# |                                                       }                                         |            |
# |                                                  else                                           |            |
# |                                                      lh->error++;                               |            |
# |                                                        return;                                  |            |
# |                                                           }                                     |            |
# |                                          lh->num_contract_reallocs++;                           |            |
# |                                            lh->num_alloc_nodes/=2;                              |            |
# |                                                  lh->pmax/=2;                                   |            |
# |                                               lh->p=lh->pmax-1;                                 |            |
# |                                                    lh->b=n;                                     |            |
# |                                                       }                                         |            |
# |                                                  else                                           |            |
# |                                                    lh->p--;                                     |            |
# |                                            lh->num_nodes--;                                     |            |
# |                                          lh->num_contracts++;                                   |            |
# |                                          n1=lh->b(int)lh->p;                                    |            |
# |                                            if (n1 == NULL)                                      |            |
# |                                              lh->b(int)lh->p=np;                                |            |
# |                                                  else                                           |            |
# |                                                       {                                         |            |
# |                                            while (n1->next != NULL)                             |            |
# |                                                      n1=n1->next;                               |            |
# |                                                  n1->next=np;                                   |            |
# |                                                       }                                         |            |
# |                                                   }'                                            |            |
# |                        'static int mmf_read_header(AVFormatContext *s)                          |      0     |
# |                                               {                                                 |            |
# |                                  MMFContext *mmf = s->priv_data;                                |            |
# |                                         unsigned int tag;                                       |            |
# |                                      AVIOContext *pb = s->pb;                                   |            |
# |                                           AVStream *st;                                         |            |
# |                                           int64_t size;                                         |            |
# |                                         int rate, params;                                       |            |
# |                                        tag = avio_rl32(pb);                                     |            |
# |                           if (tag != MKTAG(\'M\', \'M\', \'M\', \'D\'))                         |            |
# |                                      return AVERROR_INVALIDDATA;                                |            |
# |                                         avio_skip(pb, 4);                                       |            |
# |                      if ((tag & 0xffffff) != MKTAG(\'A\', \'w\', \'a\', 0)) {                   |            |
# |                          av_log(s, AV_LOG_ERROR, "Unexpected SMAF chunk %08x\                   |            |
# |                                            ", tag);                                             |            |
# |                                      return AVERROR_INVALIDDATA;                                |            |
# |                                                 }                                               |            |
# |                               mmf->data_end = avio_tell(pb) + size;                             |            |
# |                                 st = avformat_new_stream(s, NULL);                              |            |
# |                                              if (!st)                                           |            |
# |                                        return AVERROR(ENOMEM);                                  |            |
# |                     st->codecpar->codec_type            = AVMEDIA_TYPE_AUDIO;                   |            |
# |                  st->codecpar->codec_id              = AV_CODEC_ID_ADPCM_YAMAHA;                |            |
# |                            st->codecpar->sample_rate           = rate;                          |            |
# |                      st->codecpar->channels              = (params >> 7) + 1;                   |            |
# |    st->codecpar->channel_layout        = params >> 7 ? AV_CH_LAYOUT_STEREO : AV_CH_LAYOUT_MONO; |            |
# |                              st->codecpar->bits_per_coded_sample = 4;                           |            |
# |                 st->codecpar->bit_rate              = st->codecpar->sample_rate *               |            |
# |                                                   st->codecpar->bits_per_coded_sample;          |            |
# |                     avpriv_set_pts_info(st, 64, 1, st->codecpar->sample_rate);                  |            |
# |                                             return 0;                                           |            |
# |                                }', 'int avio_r8(AVIOContext *s)                                 |            |
# |                                               {                                                 |            |
# |                                   if (s->buf_ptr >= s->buf_end)                                 |            |
# |                                            fill_buffer(s);                                      |            |
# |                                    if (s->buf_ptr < s->buf_end)                                 |            |
# |                                         return *s->buf_ptr++;                                   |            |
# |                                             return 0;                                           |            |
# |                                               }'                                                |            |
# +--------------------------------------------------------------------------------------------------------------+
# FULL Dataset: (161999, 2)
# TRAIN Dataset: (26796, 2)
# VALID Dataset: (131225, 2)
#            [Initiating Fine Tuning]...                                           <ipython-input-82-b2b0b299ebbe>:85
#            [Initiating Validation]...                                            <ipython-input-82-b2b0b299ebbe>:98
# accuracy score : 0.0875, f1 score : 0.0467
# Completed 0
# accuracy score : 0.9375, f1 score : 0.8800
# Completed 10
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 20
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 30
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 40
# accuracy score : 0.7500, f1 score : 0.6407
# Completed 50
# accuracy score : 0.7625, f1 score : 0.6125
# Completed 60
# accuracy score : 0.6375, f1 score : 0.4928
# Completed 70
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 80
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 90
# accuracy score : 0.9375, f1 score : 0.8813
# Completed 100
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 110
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 120
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 130
# accuracy score : 0.8125, f1 score : 0.7324
# Completed 140
# accuracy score : 0.5375, f1 score : 0.5273
# Completed 150
# accuracy score : 0.6625, f1 score : 0.5424
# Completed 160
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 170
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 180
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 190
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 200
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 210
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 220
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 230
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 240
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 250
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 260
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 270
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 280
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 290
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 300
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 310
# accuracy score : 0.9500, f1 score : 0.8857
# Completed 320
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 330
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 340
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 350
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 360
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 370
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 380
# accuracy score : 0.4750, f1 score : 0.3933
# Completed 390
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 400
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 410
# accuracy score : 0.9125, f1 score : 0.7752
# Completed 420
# accuracy score : 0.9375, f1 score : 0.7686
# Completed 430
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 440
# accuracy score : 0.9125, f1 score : 0.7604
# Completed 450
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 460
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 470
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 480
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 490
# accuracy score : 0.9375, f1 score : 0.7333
# Completed 500
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 510
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 520
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 530
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 540
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 550
# accuracy score : 0.8500, f1 score : 0.7362
# Completed 560
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 570
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 580
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 590
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 600
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 610
# accuracy score : 0.9375, f1 score : 0.7829
# Completed 620
# accuracy score : 0.9500, f1 score : 0.8219
# Completed 630
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 640
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 650
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 660
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 670
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 680
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 690
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 700
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 710
# accuracy score : 0.9375, f1 score : 0.8318
# Completed 720
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 730
# accuracy score : 0.9500, f1 score : 0.7867
# Completed 740
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 750
# accuracy score : 0.9500, f1 score : 0.7867
# Completed 760
# accuracy score : 0.9000, f1 score : 0.7695
# Completed 770
# accuracy score : 0.8375, f1 score : 0.6391
# Completed 780
# accuracy score : 0.9125, f1 score : 0.6619
# Completed 790
# accuracy score : 0.8125, f1 score : 0.5204
# Completed 800
# accuracy score : 0.8750, f1 score : 0.6362
# Completed 810
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 820
# accuracy score : 0.9375, f1 score : 0.9273
# Completed 830
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 840
# accuracy score : 0.9000, f1 score : 0.7703
# Completed 850
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 860
# accuracy score : 0.8625, f1 score : 0.7518
# Completed 870
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 880
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 890
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 900
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 910
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 920
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 930
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 940
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 950
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 960
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 970
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 980
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 990
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1000
# accuracy score : 0.9625, f1 score : 0.9256
# Completed 1010
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1020
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1030
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1040
# accuracy score : 0.9625, f1 score : 0.8752
# Completed 1050
# accuracy score : 0.9500, f1 score : 0.7867
# Completed 1060
# accuracy score : 0.9125, f1 score : 0.7733
# Completed 1070
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1080
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1090
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1100
# accuracy score : 0.9500, f1 score : 0.9222
# Completed 1110
# accuracy score : 0.8000, f1 score : 0.6258
# Completed 1120
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 1130
# accuracy score : 0.9375, f1 score : 0.9273
# Completed 1140
# accuracy score : 0.9250, f1 score : 0.8641
# Completed 1150
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1160
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1170
# accuracy score : 0.8625, f1 score : 0.6978
# Completed 1180
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1190
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1200
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 1210
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 1220
# accuracy score : 0.8875, f1 score : 0.7635
# Completed 1230
# accuracy score : 0.9500, f1 score : 0.9333
# Completed 1240
# accuracy score : 0.8875, f1 score : 0.7651
# Completed 1250
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1260
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1270
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1280
# accuracy score : 0.9000, f1 score : 0.6724
# Completed 1290
# accuracy score : 0.9250, f1 score : 0.8280
# Completed 1300
# accuracy score : 0.8875, f1 score : 0.6686
# Completed 1310
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1320
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1330
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1340
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1350
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1360
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1370
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1380
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1390
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1400
# accuracy score : 0.9375, f1 score : 0.8324
# Completed 1410
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1420
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1430
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1440
# accuracy score : 0.9500, f1 score : 0.9333
# Completed 1450
# accuracy score : 0.7875, f1 score : 0.7263
# Completed 1460
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1470
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1480
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 1490
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1500
# accuracy score : 0.8875, f1 score : 0.7162
# Completed 1510
# accuracy score : 0.9250, f1 score : 0.7295
# Completed 1520
# accuracy score : 0.9500, f1 score : 0.8723
# Completed 1530
# accuracy score : 0.8375, f1 score : 0.7918
# Completed 1540
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1550
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1560
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 1570
# accuracy score : 0.8875, f1 score : 0.7664
# Completed 1580
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1590
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1600
# accuracy score : 0.9375, f1 score : 0.8318
# Completed 1610
# accuracy score : 0.9750, f1 score : 0.9286
# Completed 1620
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1630
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1640
# accuracy score : 0.8625, f1 score : 0.8013
# Completed 1650
# accuracy score : 0.9125, f1 score : 0.8600
# Completed 1660
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1670
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1680
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1690
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1700
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1710
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1720
# accuracy score : 0.9125, f1 score : 0.8701
# Completed 1730
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1740
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 1750
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1760
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1770
# accuracy score : 0.9125, f1 score : 0.8718
# Completed 1780
# accuracy score : 0.9500, f1 score : 0.9333
# Completed 1790
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1800
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1810
# accuracy score : 0.9500, f1 score : 0.9222
# Completed 1820
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 1830
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 1840
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 1850
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 1860
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1870
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1880
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1890
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1900
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 1910
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1920
# accuracy score : 0.9250, f1 score : 0.8267
# Completed 1930
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 1940
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1950
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1960
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 1970
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 1980
# accuracy score : 0.9500, f1 score : 0.9222
# Completed 1990
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2000
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2010
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2020
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2030
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2040
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2050
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2060
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2070
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2080
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2090
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2100
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2110
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2120
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2130
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2140
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2150
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2160
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 2170
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2180
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 2190
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2200
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2210
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2220
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2230
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2240
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2250
# accuracy score : 0.9375, f1 score : 0.8813
# Completed 2260
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2270
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2280
# accuracy score : 0.9375, f1 score : 0.8324
# Completed 2290
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2300
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2310
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2320
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2330
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2340
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 2350
# accuracy score : 0.9500, f1 score : 0.7867
# Completed 2360
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2370
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2380
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 2390
# accuracy score : 0.8875, f1 score : 0.8130
# Completed 2400
# accuracy score : 0.8125, f1 score : 0.7715
# Completed 2410
# accuracy score : 0.9125, f1 score : 0.8242
# Completed 2420
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 2430
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2440
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2450
# accuracy score : 0.9250, f1 score : 0.8009
# Completed 2460
# accuracy score : 0.9125, f1 score : 0.7251
# Completed 2470
# accuracy score : 0.9375, f1 score : 0.8800
# Completed 2480
# accuracy score : 0.9250, f1 score : 0.8152
# Completed 2490
# accuracy score : 0.8625, f1 score : 0.6461
# Completed 2500
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2510
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2520
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2530
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2540
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 2550
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2560
# accuracy score : 0.9375, f1 score : 0.8190
# Completed 2570
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2580
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2590
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2600
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2610
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2620
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2630
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2640
# accuracy score : 0.8250, f1 score : 0.7248
# Completed 2650
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2660
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 2670
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2680
# accuracy score : 0.8625, f1 score : 0.8042
# Completed 2690
# accuracy score : 0.9250, f1 score : 0.7785
# Completed 2700
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2710
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 2720
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2730
# accuracy score : 0.9000, f1 score : 0.7574
# Completed 2740
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2750
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 2760
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2770
# accuracy score : 0.9500, f1 score : 0.8219
# Completed 2780
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2790
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2800
# accuracy score : 0.9125, f1 score : 0.7114
# Completed 2810
# accuracy score : 0.9500, f1 score : 0.9333
# Completed 2820
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2830
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 2840
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2850
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 2860
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 2870
# accuracy score : 0.8875, f1 score : 0.7657
# Completed 2880
# accuracy score : 0.9000, f1 score : 0.6718
# Completed 2890
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 2900
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 2910
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2920
# accuracy score : 0.9375, f1 score : 0.7333
# Completed 2930
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 2940
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 2950
# accuracy score : 0.9250, f1 score : 0.8739
# Completed 2960
# accuracy score : 0.9125, f1 score : 0.8115
# Completed 2970
# accuracy score : 0.9500, f1 score : 0.9222
# Completed 2980
# accuracy score : 0.8500, f1 score : 0.7049
# Completed 2990
# accuracy score : 0.9375, f1 score : 0.7829
# Completed 3000
# accuracy score : 0.9250, f1 score : 0.9200
# Completed 3010
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3020
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3030
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 3040
# accuracy score : 0.9250, f1 score : 0.8280
# Completed 3050
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3060
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3070
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3080
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3090
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3100
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3110
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 3120
# accuracy score : 0.8500, f1 score : 0.6547
# Completed 3130
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3140
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 3150
# accuracy score : 0.9375, f1 score : 0.8181
# Completed 3160
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3170
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3180
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3190
# accuracy score : 0.9375, f1 score : 0.7333
# Completed 3200
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3210
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3220
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3230
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 3240
# accuracy score : 0.9250, f1 score : 0.9200
# Completed 3250
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3260
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3270
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3280
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 3290
# accuracy score : 0.9125, f1 score : 0.8701
# Completed 3300
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 3310
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3320
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3330
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3340
# accuracy score : 0.8375, f1 score : 0.6792
# Completed 3350
# accuracy score : 0.8375, f1 score : 0.6768
# Completed 3360
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 3370
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 3380
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 3390
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3400
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3410
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3420
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3430
# accuracy score : 0.8250, f1 score : 0.7762
# Completed 3440
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 3450
# accuracy score : 0.9625, f1 score : 0.8400
# Completed 3460
# accuracy score : 0.9125, f1 score : 0.8044
# Completed 3470
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3480
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3490
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3500
# accuracy score : 0.9125, f1 score : 0.7251
# Completed 3510
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3520
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3530
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3540
# accuracy score : 0.8750, f1 score : 0.7597
# Completed 3550
# accuracy score : 0.9125, f1 score : 0.8718
# Completed 3560
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3570
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3580
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3590
# accuracy score : 0.8875, f1 score : 0.7162
# Completed 3600
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3610
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3620
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3630
# accuracy score : 0.9500, f1 score : 0.8857
# Completed 3640
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3650
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 3660
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3670
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3680
# accuracy score : 0.9125, f1 score : 0.7747
# Completed 3690
# accuracy score : 0.9000, f1 score : 0.8657
# Completed 3700
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3710
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3720
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3730
# accuracy score : 0.9250, f1 score : 0.8762
# Completed 3740
# accuracy score : 0.9625, f1 score : 0.9385
# Completed 3750
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3760
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3770
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3780
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3790
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3800
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3810
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 3820
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3830
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 3840
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3850
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3860
# accuracy score : 0.9500, f1 score : 0.8851
# Completed 3870
# accuracy score : 0.9500, f1 score : 0.8857
# Completed 3880
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3890
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3900
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 3910
# accuracy score : 0.9875, f1 score : 0.9467
# Completed 3920
# accuracy score : 0.9500, f1 score : 0.8714
# Completed 3930
# accuracy score : 0.9250, f1 score : 0.8143
# Completed 3940
# accuracy score : 0.8875, f1 score : 0.8029
# Completed 3950
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 3960
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3970
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 3980
# accuracy score : 0.9625, f1 score : 0.8895
# Completed 3990
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 4000
# accuracy score : 0.9750, f1 score : 0.8933
# Completed 4010
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 4020
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 4030
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 4040
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 4050
# accuracy score : 0.9750, f1 score : 0.9429
# Completed 4060
# accuracy score : 0.9375, f1 score : 0.8324
# Completed 4070
# accuracy score : 1.0000, f1 score : 1.0000
# Completed 4080
# accuracy score : 0.9500, f1 score : 0.8362
# Completed 4090
# accuracy score : 0.8750, f1 score : 0.6629
# Completed 4100
# accuracy score : 0.9875, f1 score : 0.9467

# %%
predict = pd.read_csv('outputs/predictions.csv')
predict
# Out:
#       Unnamed: 0 Generated Text  Actual Text
# 0              0              0            0
# 1              1              0            0
# 2              2              0            0
# 3              3              0            0
# 4              4              0            0
# ...          ...            ...          ...
# 5354        5354             "0            1
# 5355        5355              0            1
# 5356        5356             #0            1
# 5357        5357              0            1
# 5358        5358              0            1
#
# [5359 rows x 3 columns]
